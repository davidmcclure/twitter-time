# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import numpy as np

# %%
from twitter_time.models import MinuteCount

# %%
def plot_series(token, title=None):
    
    series = MinuteCount.token_series(token)
    
    plt.figure(figsize=(10, 6))

    plt.title(title or '"{}"'.format(token))
    plt.xlabel('Minutes')
    plt.ylabel('Word count')
    
    plt.hist(
        np.arange(len(series)),
        bins=len(series),
        weights=series,
        edgecolor='black',
        
        zorder=3,
    )
    
    plt.show()

# %%
plot_series('temperature')

# %%
plot_series('traveled')

# %%
plot_series('tracked')

# %%
plot_series('highlights')

# %%
plot_series('readings')

# %%
plot_series('shortly')

# %%
plot_series('more')

# %%
plot_series('although')

# %%
plot_series('emotional')

# %%
plot_series('emotionally')

# %%
plot_series('tricky')

# %%
plot_series('frustration')

# %%
plot_series('eager')

# %%
plot_series('profound')

# %%
plot_series('sincere')

# %%
plot_series('curiosity')

# %%
plot_series('controlling')

# %%
plot_series('ironic')

# %%
plot_series('ironically')

# %%
plot_series('apparent')

# %%
plot_series('apparently')

# %%
plot_series('enthusiasm')

# %%
plot_series('willingness')

# %%
plot_series('tendency')

# %%
plot_series('obligations')

# %%
plot_series('conclusions')
