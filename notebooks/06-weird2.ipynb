# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
import numpy as np

# %%
from twitter_time.models import MinuteCount

# %%
def plot_series(token, title=None):
    
    series = MinuteCount.token_series(token)
    
    plt.figure(figsize=(10, 6))

    plt.title(title or '"{}"'.format(token))
    plt.xlabel('Minutes')
    plt.ylabel('Word count')
    
    plt.hist(
        np.arange(len(series)),
        bins=len(series),
        weights=series,
        edgecolor='black',
        
        zorder=3,
    )
    
    plt.show()

# %%
plot_series('more')

# %%
plot_series('quite')

# %%
plot_series('might')

# %%
plot_series('may')

# %%
plot_series('could')

# %%
plot_series('although')

# %%
plot_series('despite')

# %%
plot_series('happy')

# %%
plot_series('sad')

# %%
plot_series('tired')

# %%
plot_series('excited')

# %%
plot_series('bored')

# %%
plot_series('rather')

# %%
plot_series('fairly')

# %%
plot_series('very')

# %%
plot_series('tricky')

# %%
plot_series('clever')

# %%
plot_series('god')

# %%
plot_series('damn')

# %%
plot_series('shit')

# %%
plot_series('hell')

# %%
plot_series('fuck')

# %%
plot_series('smart')

# %%
plot_series('will')

# %%
plot_series('had')

# %%
plot_series('might')

# %%
plot_series('may')

# %%
plot_series('could')

# %%
plot_series('would')

# %%
plot_series('impossible')

# %%
plot_series('possible')

# %%
plot_series('surely')

# %%
plot_series('yes')

# %%
plot_series('hate')

# %%
plot_series('more')

# %%
plot_series('less')

# %%
plot_series('the')

# %%
plot_series('a')

# %%
plot_series('curiosity')

# %%
plot_series('beside')

# %%
plot_series('into')

# %%
plot_series('above')

# %%
plot_series('below')

# %%
plot_series('eager')

# %%
plot_series('happy')

# %%
plot_series('sad')

# %%
plot_series('depressed')

# %%
plot_series('feel')

# %%
plot_series('see')

# %%
plot_series('hear')

# %%
plot_series('smell')

# %%
plot_series('wonder')

# %%
plot_series('irony')

# %%
plot_series('spite')

# %%
plot_series('despite')

# %%
plot_series('tricky')

# %%
plot_series('although')

# %%
plot_series('weird')

# %%
plot_series('difficult')

# %%
plot_series('impossible')

# %%
plot_series('challenging')

# %%
plot_series('was')

# %%
plot_series('concerned')

# %%
plot_series('lonely')
